# %% [markdown]
# Installing necessary dependencies into the virtual environment

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install nltk
# !pip install tqdm
# !pip install transformers
# !pip install scipy
# !pip install torch
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# ...

# %% [markdown]
# Importing necessary dependencies into the virtual environment

# %%
# Importing numpy into the virtual environment
import numpy as np

# Importing pandas into the virtual environment
import pandas as pd

# Importing matplotlib into the virtual environment
import matplotlib.pyplot as plt

# Importing seaborn into the virtual environment
import seaborn as sns

# Apply the 'ggplot' style to the plots for better visual aesthetics
plt.style.use('ggplot')

# Importing nltk into the virtual environment
import nltk

# Download the 'punkt' tokenizer data
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\visma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\visma\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\visma\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\visma\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\visma\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# Data Collection and Basic analysis

# %%
# Loading the dataset into the virtual environment
review = pd.read_csv('Reviews.csv')

# %%
# Displaying the first five instances of the review dataframe
review.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
# Displaying the number of rows and columns in the dataframe
review.shape
# Out:
# (568454, 10)

# %%
# Getting necessary information about the dataframe
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
# Getting the statistical measure about the dataframe
review.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %% [markdown]
# Exploratory Data Analysis

# %%
# Checking the null values in the dataframe
review.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               26
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
# Dropping the null values in the dataframe
review = review.dropna()

# %%
# Checking if the null values are removed
review.isnull().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %%
# Checking for duplicate values in the dataframe
review.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count the number of occurrences of each unique value in the 'Score' column
score_count = review['Score'].value_counts().sort_index()

# Printing the number of unique values
print("Number of unique values in 'Score' column: ", score_count)
# Out:
# Number of unique values in 'Score' column:  Score
# 1     52264
# 2     29743
# 3     42638
# 4     80654
# 5    363102
# Name: count, dtype: int64

# %%
# Generating a visualization for the unique values in the "Score" column
num_colors = len(score_count)
colors = plt.cm.tab20.colors[:num_colors]  # Use a colormap with a distinct set of colors

# Plot the bar chart with distinct colors
score_count.plot(kind='bar', color=colors, 
                  title="Count of Reviews per Stars", 
                  figsize=(10,5))

# Add labels to the plot for clarity
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Performing Basic NLTK

# %%
# Getting a closer look about the data to be used for sentiment analysis
sentiment = review['Text'].values[50]

sentiment
# Out:
# "This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go."

# %%
# Performing word tokeniztion on the example sentence
tokens = nltk.word_tokenize(sentiment)

# Displaying the first 10 tokens
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
# Checking the Parts-Of-Speech for the example sentence
tag = nltk.pos_tag(tokens)

# Displaying the firt 10 Parts-Of-Speech tags
tag[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
# Perform Named Entity Recognition (NER) on POS-tagged words and print the result as a tree structure
entities = nltk.chunk.ne_chunk(tag)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# VADER Sentiment Scoring

# %%
# Loading necessary libraries into the dataframe
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# Intializing sentiment analyzer
sia = SentimentIntensityAnalyzer()

# %%
# Checking the snetiment of the given sentence positive sentence
sia.polarity_scores("I am thrilled for you!")
# Out:
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4926}

# %%
# Checking the snetiment of the given sentence negative sentence
sia.polarity_scores("I am sad!")
# Out:
# {'neg': 0.772, 'neu': 0.228, 'pos': 0.0, 'compound': -0.5255}

# %%
# Checking the sentiment of the example sentence
sia.polarity_scores(sentiment)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Test with a smaller subset of the dataframe
sample_review = review.head(500)  # Adjust the number as needed

res = {}
for i, row in tqdm(sample_review.iterrows(), total=len(sample_review)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)

print("Processing complete for sample data.")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Processing complete for sample data.

# %%
# Printing the sentiment of all the instances of the dataframe
vaders = pd.DataFrame(res).T

# Printing vaders
vaders
# Out:
#        neg    neu    pos  compound
# 1    0.000  0.695  0.305    0.9441
# 2    0.138  0.862  0.000   -0.5664
# 3    0.091  0.754  0.155    0.8265
# 4    0.000  1.000  0.000    0.0000
# 5    0.000  0.552  0.448    0.9468
# ..     ...    ...    ...       ...
# 496  0.000  0.554  0.446    0.9725
# 497  0.059  0.799  0.142    0.7833
# 498  0.025  0.762  0.212    0.9848
# 499  0.041  0.904  0.055    0.1280
# 500  0.000  0.678  0.322    0.9811
#
# [500 rows x 4 columns]

# %%
import pandas as pd

# Sample DataFrames (replace these with your actual data)
# review = pd.read_csv('review.csv')  # or however you load your DataFrame
# vaders = pd.read_csv('vaders.csv')  # or however you load your DataFrame

# Rename existing 'Id' column in 'vaders' if it exists
if 'Id' in vaders.columns:
    vaders = vaders.rename(columns={'Id': 'old_Id'})

# Reset index and rename the index column to 'Id'
vaders = vaders.reset_index().rename(columns={'index': 'Id'})

# Drop duplicate columns if they exist
vaders = vaders.loc[:, ~vaders.columns.duplicated()]

# Merge 'vaders' with 'review' on 'Id'
vaders = review.merge(vaders, how='left', on='Id')

# %%
vaders.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text', 'neg',
#        'neu', 'pos', 'compound'],
#       dtype='object')

# %%
# List of columns to drop (those ending with '_y')
cols_to_drop = [col for col in vaders.columns if col.endswith('_y')]

# Drop the columns
vaders = vaders.drop(columns=cols_to_drop)

# %%
# Now we have sentiment score and metadata
vaders.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# Plot VADER Results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame setup (replace with your actual DataFrame)
# vaders = pd.read_csv('your_data.csv')

# Plot with different colors based on 'Score_x'
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=vaders, x='Score', y='compound', hue='Score', palette='viridis')
ax.set_title("Compound Score by Amazon Star Review")
plt.show()

# %%
# Define custom colors for each subplot
color_palettes = [
    sns.color_palette("Blues_d"),  # Color palette for Positive Scores
    sns.color_palette("Greens_d"), # Color palette for Neutral Scores
    sns.color_palette("Reds_d")    # Color palette for Negative Scores
]

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot on each subplot with different color palettes
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0], palette=color_palettes[0])
axs[0].set_title('Positive Scores')

sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1], palette=color_palettes[1])
axs[1].set_title('Neutral Scores')

sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2], palette=color_palettes[2])
axs[2].set_title('Negative Scores')

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\visma\AppData\Local\Temp\ipykernel_161024\1665606805.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0], palette=color_palettes[0])
# C:\Users\visma\AppData\Local\Temp\ipykernel_161024\1665606805.py:12: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0], palette=color_palettes[0])
# C:\Users\visma\AppData\Local\Temp\ipykernel_161024\1665606805.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1], palette=color_palettes[1])
# ...

# %% [markdown]
# Roberta Pre-trained Model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.4.1+cpu
# False

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# c:\Users\visma\OneDrive\Desktop\sentiment-analysis\sentiment-analysis\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# ...

# %%
# VADER results on example
print(sentiment)
sia.polarity_scores(sentiment)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run for Roberta Model
encoded_text = tokenizer(sentiment, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': np.float32(0.97635514), 'roberta_neu': np.float32(0.020687465), 'roberta_pos': np.float32(0.0029573692)}

# %%
def polarity_scores_roberta(sentiment):
    encoded_text = tokenizer(sentiment, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
sample_review = review.head(500)
res = {}
for i, row in tqdm(sample_review.iterrows(),  total=len(sample_review)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(review, how='left')

# %% [markdown]
# Compare Scores between models

# %%
results_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %% [markdown]
# Combine and compare

# %%
sns.pairplot(data=results_df,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()

# %% [markdown]
# Review Examples

# %%
results_df.query('Score == 1') \
    .sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# 'I felt energized within five minutes, but it lasted for about 45 minutes. I paid $3.99 for this drink. I could have just drunk a cup of coffee and saved my money.'

# %%
results_df.query('Score == 1') \
    .sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %% [markdown]
# Negative sentiment with a 5 star review

# %%
# Roberta model
results_df.query('Score == 5') \
    .sort_values('roberta_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
# Vader model
results_df.query('Score == 5') \
    .sort_values('vader_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %% [markdown]
# Transformer Pipeline

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...

# %%
sent_pipeline('I recently purchased the XYZ Noise-Canceling Headphones, and overall, I’m quite impressed with their performance.')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9996739625930786}]

# %%
sent_pipeline('The XYZ Noise-Canceling Headphones offer decent noise cancellation and comfort but have average audio quality and a bulky design.')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9963058233261108}]
